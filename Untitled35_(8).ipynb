# %%
# --- 0. Global Constants ---
# Material Properties
E = 200 * (10**9)  # N/m^2 (Modulus Elastisitas Baja)
sigma_izin = 160 * (10**6)  # N/m^2 (Tegangan Izin Baja)
density_steel = 7850  # kg/m^3 (Densitas Baja)

# Loading and Geometry (KONSTAN)
P = 40000    # N (Beban Terpusat: 500 kg = 5000 N)
L = 5.0      # m (Bentang Balok: KONSTAN 3.0 m)

# Numerical Stability Constant
EPSILON = 1e-9 # Define EPSILON as a small positive number

# --- 1. Helper Functions for IWF Properties ---
# Fungsi-fungsi ini mengasumsikan input sudah divalidasi oleh is_geometry_valid
def calculate_I_x(h, bf, tf, tw):
    """Menghitung Momen Inersia (Ix) untuk penampang IWF."""
    I_x_flange_centroid = (1/12) * bf * tf**3
    A_flange = bf * tf
    y_flange = (h/2) - (tf/2)
    I_x_flange = 2 * (I_x_flange_centroid + A_flange * y_flange**2)

    I_x_web = (1/12) * tw * (h - 2*tf)**3
    return I_x_flange + I_x_web

def calculate_W_z(h, I_x_val):
    """Menghitung Modulus Penampang (Wz) untuk penampang IWF."""
    if h <= EPSILON: # Proteksi dari h mendekati nol
        return EPSILON # Mengembalikan nilai kecil jika h tidak valid
    return I_x_val / (h / 2)

def calculate_area(h, bf, tf, tw):
    """Menghitung luas penampang (A) untuk penampang IWF."""
    return 2 * (bf * tf) + (h - 2*tf) * tw

# %%
# prompt: tambahkan fungsi objective minimize volume balok dimana volume = (h*tw + 2*bf*tf)*L

# --- 2. Objective Function ---
def objective_function(params):
    """Fungsi objektif untuk diminimalkan (Volume balok)."""
    h, bf, tf, tw = params
    # Volume = Luas Penampang * Panjang
    area = (h * tw + 2 * bf * tf)
    volume = area * L
    return volume

# %%
# prompt: Visualisasi Volume Baja Profil sebagai Fungsi dari Tinggi dan Lebar Flange

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# --- 5. Visualisasi Volume ---

# Buat rentang nilai untuk bf dan h
# Pilih rentang yang masuk akal berdasarkan profil IWF standar
bf_range = np.linspace(0.1, 0.5, 50)  # Rentang lebar flange (m)
h_range = np.linspace(0.2, 1.0, 50)  # Rentang tinggi profil (m)

# Asumsi nilai tf dan tw yang tetap untuk simplifikasi visualisasi
# Anda bisa menggunakan nilai tipikal dari profil standar
tf_fixed = 0.01  # Tebal flange (m) - contoh
tw_fixed = 0.006  # Tebal web (m) - contoh

# Buat grid untuk bf dan h
BF, H = np.meshgrid(bf_range, h_range)

# Hitung volume untuk setiap kombinasi bf dan h
VOLUME = objective_function([H, BF, np.full_like(BF, tf_fixed), np.full_like(BF, tw_fixed)])

# Buat plot 3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot permukaan
surf = ax.plot_surface(BF, H, VOLUME, cmap='viridis', edgecolor='none')

# Atur label sumbu
ax.set_xlabel('Lebar Flange, bf (m)')
ax.set_ylabel('Tinggi Profil, h (m)')
ax.set_zlabel('Volume Baja Profil (m^3)')
ax.set_title('Visualisasi Volume Baja Profil sebagai Fungsi dari Tinggi dan Lebar Flange\n(dengan tf dan tw diasumsikan tetap)')

# Tambahkan color bar
fig.colorbar(surf, label='Volume (m^3)')

plt.show()

# %%
# prompt: tambah kombinasi untuk besaran nilai h, bf, tf, tw. h dan bf nilainya berada antara 100-500 (100,150,200,250,300,350,400,450 dan 500) namun nilai bf adalah tidak boleh lebih besar dari nilai h. nilai tf dan tw 5 mm, 6 mm , 7 mm, 9 mm dan 12 mm. namun nilai tf harus lebih bsar dari tw

import numpy as np
def generate_valid_combinations():
    """
    Menghasilkan kombinasi parameter h, bf, tf, tw yang valid
    berdasarkan batasan yang diberikan.
    """
    h_values = np.array([100, 150, 200, 250, 300, 350, 400, 450, 500]) * 1e-3 # Convert mm to meters
    bf_values = np.array([100, 150, 200, 250, 300, 350, 400, 450, 500]) * 1e-3 # Convert mm to meters
    t_values = np.array([5, 6, 7, 9, 12]) * 1e-3 # Convert mm to meters

    valid_combinations = []
    for h in h_values:
        for bf in bf_values:
            # bf tidak boleh lebih besar dari h
            if bf <= h:
                for tf in t_values:
                    for tw in t_values:
                        # tf harus lebih besar dari tw
                        if tf > tw:
                            valid_combinations.append((h, bf, tf, tw))
    return valid_combinations

# Example usage:
valid_configs = generate_valid_combinations()
print(f"Generated {len(valid_configs)} valid combinations.")
# print(valid_configs[:10]) # Print first 10 combinations as an example
# Out:
# Generated 450 valid combinations.

# %%
# prompt: tampilkan 450 valid combinations.

print("Valid Combinations:")
for i, combo in enumerate(valid_configs[:450]): # Displaying the first 450 valid combinations
    print(f"Combination {i+1}: h={combo[0]:.4f} m, bf={combo[1]:.4f} m, tf={combo[2]:.4f} m, tw={combo[3]:.4f} m")
# Out:
# Valid Combinations:
# Combination 1: h=0.1000 m, bf=0.1000 m, tf=0.0060 m, tw=0.0050 m
# Combination 2: h=0.1000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Combination 3: h=0.1000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0060 m
# Combination 4: h=0.1000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0050 m
# Combination 5: h=0.1000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0060 m
# Combination 6: h=0.1000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0070 m
# Combination 7: h=0.1000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0050 m
# Combination 8: h=0.1000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0060 m
# Combination 9: h=0.1000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0070 m
# Combination 10: h=0.1000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0090 m
# Combination 11: h=0.1500 m, bf=0.1000 m, tf=0.0060 m, tw=0.0050 m
# Combination 12: h=0.1500 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Combination 13: h=0.1500 m, bf=0.1000 m, tf=0.0070 m, tw=0.0060 m
# Combination 14: h=0.1500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0050 m
# Combination 15: h=0.1500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0060 m
# Combination 16: h=0.1500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0070 m
# Combination 17: h=0.1500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0050 m
# Combination 18: h=0.1500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0060 m
# Combination 19: h=0.1500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0070 m
# Combination 20: h=0.1500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0090 m
# Combination 21: h=0.1500 m, bf=0.1500 m, tf=0.0060 m, tw=0.0050 m
# Combination 22: h=0.1500 m, bf=0.1500 m, tf=0.0070 m, tw=0.0050 m
# Combination 23: h=0.1500 m, bf=0.1500 m, tf=0.0070 m, tw=0.0060 m
# Combination 24: h=0.1500 m, bf=0.1500 m, tf=0.0090 m, tw=0.0050 m
# Combination 25: h=0.1500 m, bf=0.1500 m, tf=0.0090 m, tw=0.0060 m
# Combination 26: h=0.1500 m, bf=0.1500 m, tf=0.0090 m, tw=0.0070 m
# Combination 27: h=0.1500 m, bf=0.1500 m, tf=0.0120 m, tw=0.0050 m
# Combination 28: h=0.1500 m, bf=0.1500 m, tf=0.0120 m, tw=0.0060 m
# Combination 29: h=0.1500 m, bf=0.1500 m, tf=0.0120 m, tw=0.0070 m
# Combination 30: h=0.1500 m, bf=0.1500 m, tf=0.0120 m, tw=0.0090 m
# Combination 31: h=0.2000 m, bf=0.1000 m, tf=0.0060 m, tw=0.0050 m
# Combination 32: h=0.2000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Combination 33: h=0.2000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0060 m
# Combination 34: h=0.2000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0050 m
# Combination 35: h=0.2000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0060 m
# Combination 36: h=0.2000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0070 m
# Combination 37: h=0.2000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0050 m
# Combination 38: h=0.2000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0060 m
# Combination 39: h=0.2000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0070 m
# Combination 40: h=0.2000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0090 m
# Combination 41: h=0.2000 m, bf=0.1500 m, tf=0.0060 m, tw=0.0050 m
# Combination 42: h=0.2000 m, bf=0.1500 m, tf=0.0070 m, tw=0.0050 m
# Combination 43: h=0.2000 m, bf=0.1500 m, tf=0.0070 m, tw=0.0060 m
# Combination 44: h=0.2000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0050 m
# Combination 45: h=0.2000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0060 m
# Combination 46: h=0.2000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0070 m
# Combination 47: h=0.2000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0050 m
# Combination 48: h=0.2000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0060 m
# Combination 49: h=0.2000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0070 m
# Combination 50: h=0.2000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0090 m
# Combination 51: h=0.2000 m, bf=0.2000 m, tf=0.0060 m, tw=0.0050 m
# Combination 52: h=0.2000 m, bf=0.2000 m, tf=0.0070 m, tw=0.0050 m
# Combination 53: h=0.2000 m, bf=0.2000 m, tf=0.0070 m, tw=0.0060 m
# Combination 54: h=0.2000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0050 m
# Combination 55: h=0.2000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0060 m
# Combination 56: h=0.2000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0070 m
# Combination 57: h=0.2000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0050 m
# Combination 58: h=0.2000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0060 m
# Combination 59: h=0.2000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0070 m
# Combination 60: h=0.2000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0090 m
# Combination 61: h=0.2500 m, bf=0.1000 m, tf=0.0060 m, tw=0.0050 m
# Combination 62: h=0.2500 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Combination 63: h=0.2500 m, bf=0.1000 m, tf=0.0070 m, tw=0.0060 m
# Combination 64: h=0.2500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0050 m
# Combination 65: h=0.2500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0060 m
# Combination 66: h=0.2500 m, bf=0.1000 m, tf=0.0090 m, tw=0.0070 m
# Combination 67: h=0.2500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0050 m
# Combination 68: h=0.2500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0060 m
# Combination 69: h=0.2500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0070 m
# Combination 70: h=0.2500 m, bf=0.1000 m, tf=0.0120 m, tw=0.0090 m
# Combination 71: h=0.2500 m, bf=0.1500 m, tf=0.0060 m, tw=0.0050 m
# Combination 72: h=0.2500 m, bf=0.1500 m, tf=0.0070 m, tw=0.0050 m
# Combination 73: h=0.2500 m, bf=0.1500 m, tf=0.0070 m, tw=0.0060 m
# Combination 74: h=0.2500 m, bf=0.1500 m, tf=0.0090 m, tw=0.0050 m
# Combination 75: h=0.2500 m, bf=0.1500 m, tf=0.0090 m, tw=0.0060 m
# Combination
# Combination 356: h=0.4500 m, bf=0.4500 m, tf=0.0090 m, tw=0.0070 m
# Combination 357: h=0.4500 m, bf=0.4500 m, tf=0.0120 m, tw=0.0050 m
# Combination 358: h=0.4500 m, bf=0.4500 m, tf=0.0120 m, tw=0.0060 m
# Combination 359: h=0.4500 m, bf=0.4500 m, tf=0.0120 m, tw=0.0070 m
# Combination 360: h=0.4500 m, bf=0.4500 m, tf=0.0120 m, tw=0.0090 m
# Combination 361: h=0.5000 m, bf=0.1000 m, tf=0.0060 m, tw=0.0050 m
# Combination 362: h=0.5000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Combination 363: h=0.5000 m, bf=0.1000 m, tf=0.0070 m, tw=0.0060 m
# Combination 364: h=0.5000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0050 m
# Combination 365: h=0.5000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0060 m
# Combination 366: h=0.5000 m, bf=0.1000 m, tf=0.0090 m, tw=0.0070 m
# Combination 367: h=0.5000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0050 m
# Combination 368: h=0.5000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0060 m
# Combination 369: h=0.5000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0070 m
# Combination 370: h=0.5000 m, bf=0.1000 m, tf=0.0120 m, tw=0.0090 m
# Combination 371: h=0.5000 m, bf=0.1500 m, tf=0.0060 m, tw=0.0050 m
# Combination 372: h=0.5000 m, bf=0.1500 m, tf=0.0070 m, tw=0.0050 m
# Combination 373: h=0.5000 m, bf=0.1500 m, tf=0.0070 m, tw=0.0060 m
# Combination 374: h=0.5000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0050 m
# Combination 375: h=0.5000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0060 m
# Combination 376: h=0.5000 m, bf=0.1500 m, tf=0.0090 m, tw=0.0070 m
# Combination 377: h=0.5000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0050 m
# Combination 378: h=0.5000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0060 m
# Combination 379: h=0.5000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0070 m
# Combination 380: h=0.5000 m, bf=0.1500 m, tf=0.0120 m, tw=0.0090 m
# Combination 381: h=0.5000 m, bf=0.2000 m, tf=0.0060 m, tw=0.0050 m
# Combination 382: h=0.5000 m, bf=0.2000 m, tf=0.0070 m, tw=0.0050 m
# Combination 383: h=0.5000 m, bf=0.2000 m, tf=0.0070 m, tw=0.0060 m
# Combination 384: h=0.5000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0050 m
# Combination 385: h=0.5000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0060 m
# Combination 386: h=0.5000 m, bf=0.2000 m, tf=0.0090 m, tw=0.0070 m
# Combination 387: h=0.5000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0050 m
# Combination 388: h=0.5000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0060 m
# Combination 389: h=0.5000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0070 m
# Combination 390: h=0.5000 m, bf=0.2000 m, tf=0.0120 m, tw=0.0090 m
# Combination 391: h=0.5000 m, bf=0.2500 m, tf=0.0060 m, tw=0.0050 m
# Combination 392: h=0.5000 m, bf=0.2500 m, tf=0.0070 m, tw=0.0050 m
# Combination 393: h=0.5000 m, bf=0.2500 m, tf=0.0070 m, tw=0.0060 m
# Combination 394: h=0.5000 m, bf=0.2500 m, tf=0.0090 m, tw=0.0050 m
# Combination 395: h=0.5000 m, bf=0.2500 m, tf=0.0090 m, tw=0.0060 m
# Combination 396: h=0.5000 m, bf=0.2500 m, tf=0.0090 m, tw=0.0070 m
# Combination 397: h=0.5000 m, bf=0.2500 m, tf=0.0120 m, tw=0.0050 m
# Combination 398: h=0.5000 m, bf=0.2500 m, tf=0.0120 m, tw=0.0060 m
# Combination 399: h=0.5000 m, bf=0.2500 m, tf=0.0120 m, tw=0.0070 m
# Combination 400: h=0.5000 m, bf=0.2500 m, tf=0.0120 m, tw=0.0090 m
# Combination 401: h=0.5000 m, bf=0.3000 m, tf=0.0060 m, tw=0.0050 m
# Combination 402: h=0.5000 m, bf=0.3000 m, tf=0.0070 m, tw=0.0050 m
# Combination 403: h=0.5000 m, bf=0.3000 m, tf=0.0070 m, tw=0.0060 m
# Combination 404: h=0.5000 m, bf=0.3000 m, tf=0.0090 m, tw=0.0050 m
# Combination 405: h=0.5000 m, bf=0.3000 m, tf=0.0090 m, tw=0.0060 m
# Combination 406: h=0.5000 m, bf=0.3000 m, tf=0.0090 m, tw=0.0070 m
# Combination 407: h=0.5000 m, bf=0.3000 m, tf=0.0120 m, tw=0.0050 m
# Combination 408: h=0.5000 m, bf=0.3000 m, tf=0.0120 m, tw=0.0060 m
# Combination 409: h=0.5000 m, bf=0.3000 m, tf=0.0120 m, tw=0.0070 m
# Combination 410: h=0.5000 m, bf=0.3000 m, tf=0.0120 m, tw=0.0090 m
# Combination 411: h=0.5000 m, bf=0.3500 m, tf=0.0060 m, tw=0.0050 m
# Combination 412: h=0.5000 m, bf=0.3500 m, tf=0.0070 m, tw=0.0050 m
# Combination 413: h=0.5000 m, bf=0.3500 m, tf=0.0070 m, tw=0.0060 m
# Combination 414: h=0.5000 m, bf=0.3500 m, tf=0.0090 m, tw=0.0050 m
# Combination 415: h=0.5000 m, bf=0.3500 m, tf=0.0090 m, tw=0.0060 m
# Combination 416: h=0.5000 m, bf=0.3500 m, tf=0.0090 m, tw=0.0070 m
# Combination 417: h=0.5000 m, bf=0.3500 m, tf=0.0120 m, tw=0.0050 m
# Combination 418: h=0.5000 m, bf=0.3500 m, tf=0.0120 m, tw=0.0060 m
# Combination 419: h=0.5000 m, bf=0.3500 m, tf=0.0120 m, tw=0.0070 m
# Combination 420: h=0.5000 m, bf=0.3500 m, tf=0.0120 m, tw=0.0090 m
# Combination 421: h=0.5000 m, bf=0.4000 m, tf=0.0060 m, tw=0.0050 m
# Combination 422: h=0.5000 m, bf=0.4000 m, tf=0.0070 m, tw=0.0050 m
# Combination 423: h=0.5000 m, bf=0.4000 m, tf=0.0070 m, tw=0.0060 m
# Combination 424: h=0.5000 m, bf=0.4000 m, tf=0.0090 m, tw=0.0050 m
# Combination 425: h=0.5000 m, bf=0.4000 m, tf=0.0090 m, tw=0.0060 m
# Combination 426: h=0.5000 m, bf=0.4000 m, tf=0.0090 m, tw=0.0070 m
# Combination 427: h=0.5000 m, bf=0.4000 m, tf=0.0120 m, tw=0.0050 m
# Combination 428: h=0.5000 m, bf=0.4000 m, tf=0.0120 m, tw=0.0060 m
# Combination 429: h=0.5000 m, bf=0.4000 m, tf=0.0120 m, tw=0.0070 m
# Combination 430: h=0.5000 m, bf=0.4000 m, tf=0.0120 m, tw=0.0090 m
# Combination 431: h=0.5000 m, bf=0.4500 m, tf=0.0060 m, tw=0.0050 m
# Combination 432: h=0.5000 m, bf=0.4500 m, tf=0.0070 m, tw=0.0050 m
# Combination 433: h=0.5000 m, bf=0.4500 m, tf=0.0070 m, tw=0.0060 m
# Combination 434: h=0.5000 m, bf=0.4500 m, tf=0.0090 m, tw=0.0050 m
# Combination 435: h=0.5000 m, bf=0.4500 m, tf=0.0090 m, tw=0.0060 m
# Combination 436: h=0.5000 m, bf=0.4500 m, tf=0.0090 m, tw=0.0070 m
# Combination 437: h=0.5000 m, bf=0.4500 m, tf=0.0120 m, tw=0.0050 m
# Combination 438: h=0.5000 m, bf=0.4500 m, tf=0.0120 m, tw=0.0060 m
# Combination 439: h=0.5000 m, bf=0.4500 m, tf=0.0120 m, tw=0.0070 m
# Combination 440: h=0.5000 m, bf=0.4500 m, tf=0.0120 m, tw=0.0090 m
# Combination 441: h=0.5000 m, bf=0.5000 m, tf=0.0060 m, tw=0.0050 m
# Combination 442: h=0.5000 m, bf=0.5000 m, tf=0.0070 m, tw=0.0050 m
# Combination 443: h=0.5000 m, bf=0.5000 m, tf=0.0070 m, tw=0.0060 m
# Combination 444: h=0.5000 m, bf=0.5000 m, tf=0.0090 m, tw=0.0050 m
# Combination 445: h=0.5000 m, bf=0.5000 m, tf=0.0090 m, tw=0.0060 m
# Combination 446: h=0.5000 m, bf=0.5000 m, tf=0.0090 m, tw=0.0070 m
# Combination 447: h=0.5000 m, bf=0.5000 m, tf=0.0120 m, tw=0.0050 m
# Combination 448: h=0.5000 m, bf=0.5000 m, tf=0.0120 m, tw=0.0060 m
# Combination 449: h=0.5000 m, bf=0.5000 m, tf=0.0120 m, tw=0.0070 m
# Combination 450: h=0.5000 m, bf=0.5000 m, tf=0.0120 m, tw=0.0090 m

# %%
# prompt: tambah konstrain untuk balok yang dengan tumpuan kiri kanan dengan beban terpusat tengah 1. Kendala lendutan: delta_actual <= delta_izin, 2. Kendala tegangan: sigma_actual <= sigma_izin
# dan lakukan uji coba terhadap 450 valid combinations.

import numpy as np
# --- 3. Constraint Functions ---
def deflection_constraint(params):
    """Kendala Lendutan: delta_actual <= delta_izin."""
    h, bf, tf, tw = params
    I_x_val = calculate_I_x(h, bf, tf, tw)

    # Proteksi dari I_x_val mendekati nol (jika geometri tidak valid)
    if I_x_val <= np.finfo(float).eps:
        return -1 # Mengembalikan nilai negatif untuk menandakan pelanggaran kendala

    # Rumus lendutan maksimum untuk balok sederhana dengan beban terpusat di tengah
    delta_actual = (P * L**3) / (48 * E * I_x_val)

    # Asumsi delta_izin (misal: L/360 untuk balok struktural)
    delta_izin = L / 360

    return delta_izin - delta_actual # Harus >= 0 untuk terpenuhi

def stress_constraint(params):
    """Kendala Tegangan Lentur: sigma_actual <= sigma_izin."""
    h, bf, tf, tw = params
    I_x_val = calculate_I_x(h, bf, tf, tw)

    # Proteksi dari I_x_val mendekati nol
    if I_x_val <= np.finfo(float).eps:
        return -1 # Mengembalikan nilai negatif untuk menandakan pelanggaran kendala

    W_z_val = calculate_W_z(h, I_x_val)

    # Proteksi dari W_z_val mendekati nol
    if W_z_val <= np.finfo(float).eps:
         return -1 # Mengembalikan nilai negatif untuk menandakan pelanggaran kendala

    # Rumus momen lentur maksimum untuk balok sederhana dengan beban terpusat di tengah
    M_max = (P * L) / 4

    sigma_actual = M_max / W_z_val

    return sigma_izin - sigma_actual # Harus >= 0 untuk terpenuhi

# --- 4. Combine Constraints and Test Combinations ---
constraints = [
    {'type': 'ineq', 'fun': deflection_constraint},
    {'type': 'ineq', 'fun': stress_constraint}
]

print("\nTesting Valid Combinations against Constraints:")
passing_combinations = []

# Limit to the first 450 combinations for testing as requested
for i, combo in enumerate(valid_configs[:450]):
    h, bf, tf, tw = combo
    params = [h, bf, tf, tw]

    # Check if all constraints are satisfied
    deflection_ok = deflection_constraint(params) >= 0
    stress_ok = stress_constraint(params) >= 0

    if deflection_ok and stress_ok:
        passing_combinations.append(combo)
        print(f"Combination {i+1} (h={h:.4f}, bf={bf:.4f}, tf={tf:.4f}, tw={tw:.4f}) PASSED all constraints.")
    # else:
        # print(f"Combination {i+1} (h={h:.4f}, bf={bf:.4f}, tf={tf:.4f}, tw={tw:.4f}) FAILED constraints (Deflection: {deflection_constraint(params):.4f}, Stress: {stress_constraint(params):.4f}).")

print(f"\nFound {len(passing_combinations)} combinations that passed all constraints.")

# You can further process or analyze the passing_combinations list,
# for example, finding the one with the minimum volume.
if passing_combinations:
    best_volume = float('inf')
    best_combo = None

    for combo in passing_combinations:
        current_volume = objective_function(combo)
        if current_volume < best_volume:
            best_volume = current_volume
            best_combo = combo

    print(f"\nCombination with minimum volume among passing combinations:")
    print(f"h={best_combo[0]:.4f} m, bf={best_combo[1]:.4f} m, tf={best_combo[2]:.4f} m, tw={best_combo[3]:.4f} m")
    print(f"Minimum Volume: {best_volume:.6f} m^3")
else:
    print("\nNo combinations found that satisfy all constraints within the first 450 generated.")
# Out:
# Testing Valid Combinations against Constraints:
# Combination 57 (h=0.2000, bf=0.2000, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 58 (h=0.2000, bf=0.2000, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 59 (h=0.2000, bf=0.2000, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 60 (h=0.2000, bf=0.2000, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 68 (h=0.2500, bf=0.1000, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 69 (h=0.2500, bf=0.1000, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 70 (h=0.2500, bf=0.1000, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 74 (h=0.2500, bf=0.1500, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 75 (h=0.2500, bf=0.1500, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 76 (h=0.2500, bf=0.1500, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 77 (h=0.2500, bf=0.1500, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 78 (h=0.2500, bf=0.1500, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 79 (h=0.2500, bf=0.1500, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 80 (h=0.2500, bf=0.1500, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 81 (h=0.2500, bf=0.2000, tf=0.0060, tw=0.0050) PASSED all constraints.
# Combination 82 (h=0.2500, bf=0.2000, tf=0.0070, tw=0.0050) PASSED all constraints.
# Combination 83 (h=0.2500, bf=0.2000, tf=0.0070, tw=0.0060) PASSED all constraints.
# Combination 84 (h=0.2500, bf=0.2000, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 85 (h=0.2500, bf=0.2000, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 86 (h=0.2500, bf=0.2000, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 87 (h=0.2500, bf=0.2000, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 88 (h=0.2500, bf=0.2000, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 89 (h=0.2500, bf=0.2000, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 90 (h=0.2500, bf=0.2000, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 91 (h=0.2500, bf=0.2500, tf=0.0060, tw=0.0050) PASSED all constraints.
# Combination 92 (h=0.2500, bf=0.2500, tf=0.0070, tw=0.0050) PASSED all constraints.
# Combination 93 (h=0.2500, bf=0.2500, tf=0.0070, tw=0.0060) PASSED all constraints.
# Combination 94 (h=0.2500, bf=0.2500, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 95 (h=0.2500, bf=0.2500, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 96 (h=0.2500, bf=0.2500, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 97 (h=0.2500, bf=0.2500, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 98 (h=0.2500, bf=0.2500, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 99 (h=0.2500, bf=0.2500, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 100 (h=0.2500, bf=0.2500, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 104 (h=0.3000, bf=0.1000, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 105 (h=0.3000, bf=0.1000, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 106 (h=0.3000, bf=0.1000, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 107 (h=0.3000, bf=0.1000, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 108 (h=0.3000, bf=0.1000, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 109 (h=0.3000, bf=0.1000, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 110 (h=0.3000, bf=0.1000, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 111 (h=0.3000, bf=0.1500, tf=0.0060, tw=0.0050) PASSED all constraints.
# Combination 112 (h=0.3000, bf=0.1500, tf=0.0070, tw=0.0050) PASSED all constraints.
# Combination 113 (h=0.3000, bf=0.1500, tf=0.0070, tw=0.0060) PASSED all constraints.
# Combination 114 (h=0.3000, bf=0.1500, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 115 (h=0.3000, bf=0.1500, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 116 (h=0.3000, bf=0.1500, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 117 (h=0.3000, bf=0.1500, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 118 (h=0.3000, bf=0.1500, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 119 (h=0.3000, bf=0.1500, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 120 (h=0.3000, bf=0.1500, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 121 (h=0.3000, bf=0.2000, tf=0.0060, tw=0.0050) PASSED all constraints.
# Combination 122 (h=0.3000, bf=0.2000, tf=0.0070, tw=0.0050) PASSED all constraints.
# Combination 123 (h=0.3000, bf=0.2000, tf=0.0070, tw=0.0060) PASSED all constraints.
# Combination 124 (h=0.3000, bf=0.2000, tf=0.0090, tw=0.0050) PASSED all constraints.
# Combination 125 (h=0.3000, bf=0.2000, tf=0.0090, tw=0.0060) PASSED all constraints.
# Combination 126 (h=0.3000, bf=0.2000, tf=0.0090, tw=0.0070) PASSED all constraints.
# Combination 127 (h=0.3000, bf=0.2000, tf=0.0120, tw=0.0050) PASSED all constraints.
# Combination 128 (h=0.3000, bf=0.2000, tf=0.0120, tw=0.0060) PASSED all constraints.
# Combination 129 (h=0.3000, bf=0.2000, tf=0.0120, tw=0.0070) PASSED all constraints.
# Combination 130 (h=0.3000, bf=0.2000, tf=0.0120, tw=0.0090) PASSED all constraints.
# Combination 131 (h=0.3000, bf=0.2500, tf=0.0060, tw=0.0050) PASSED all constraints.
# Combination
 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Minimum Volume: 0.015750 m^3

# %%
# prompt: code untuk menampilkan komnasi yang gagal melewati konstrain

print("\nFailed Combinations:")
failed_combinations = []
for i, combo in enumerate(valid_configs[:450]):
    h, bf, tf, tw = combo
    params = [h, bf, tf, tw]

    # Check if any constraint is NOT satisfied
    deflection_ok = deflection_constraint(params) >= 0
    stress_ok = stress_constraint(params) >= 0

    if not (deflection_ok and stress_ok):
        failed_combinations.append((combo, deflection_constraint(params), stress_constraint(params)))
        print(f"Combination {i+1} (h={h:.4f}, bf={bf:.4f}, tf={tf:.4f}, tw={tw:.4f}) FAILED constraints (Deflection: {deflection_constraint(params):.4f}, Stress: {stress_constraint(params):.4f}).")

print(f"\nFound {len(failed_combinations)} combinations that failed one or more constraints within the first 450 generated.")

# You can further process or analyze the failed_combinations list if needed.
# Out:
# Failed Combinations:
# Combination 1 (h=0.1000, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.1634, Stress: -690818600.9366).
# Combination 2 (h=0.1000, bf=0.1000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.1440, Stress: -598060456.8376).
# Combination 3 (h=0.1000, bf=0.1000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.1415, Stress: -586069407.9313).
# Combination 4 (h=0.1000, bf=0.1000, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.1174, Stress: -469986871.0736).
# Combination 5 (h=0.1000, bf=0.1000, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.1159, Stress: -462776066.6659).
# Combination 6 (h=0.1000, bf=0.1000, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.1144, Stress: -455728463.4192).
# Combination 7 (h=0.1000, bf=0.1000, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: -0.0933, Stress: -354603768.8208).
# Combination 8 (h=0.1000, bf=0.1000, tf=0.0120, tw=0.0060) FAILED constraints (Deflection: -0.0925, Stress: -350757784.7659).
# Combination 9 (h=0.1000, bf=0.1000, tf=0.0120, tw=0.0070) FAILED constraints (Deflection: -0.0917, Stress: -346968861.5669).
# Combination 10 (h=0.1000, bf=0.1000, tf=0.0120, tw=0.0090) FAILED constraints (Deflection: -0.0902, Stress: -339557192.5046).
# Combination 11 (h=0.1500, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0573, Stress: -352334976.9039).
# Combination 12 (h=0.1500, bf=0.1000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0495, Stress: -296705904.1315).
# Combination 13 (h=0.1500, bf=0.1000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0480, Stress: -285336718.8952).
# Combination 14 (h=0.1500, bf=0.1000, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0386, Stress: -218141600.4163).
# Combination 15 (h=0.1500, bf=0.1000, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0376, Stress: -210971839.3793).
# Combination 16 (h=0.1500, bf=0.1000, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0367, Stress: -204068903.9720).
# Combination 17 (h=0.1500, bf=0.1000, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: -0.0285, Stress: -145158645.8768).
# Combination 18 (h=0.1500, bf=0.1000, tf=0.0120, tw=0.0060) FAILED constraints (Deflection: -0.0279, Stress: -141074522.9294).
# Combination 19 (h=0.1500, bf=0.1000, tf=0.0120, tw=0.0070) FAILED constraints (Deflection: -0.0274, Stress: -137098276.7825).
# Combination 20 (h=0.1500, bf=0.1000, tf=0.0120, tw=0.0090) FAILED constraints (Deflection: -0.0263, Stress: -129452758.2995).
# Combination 21 (h=0.1500, bf=0.1500, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0360, Stress: -199483608.9854).
# Combination 22 (h=0.1500, bf=0.1500, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0303, Stress: -158001244.8689).
# Combination 23 (h=0.1500, bf=0.1500, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0295, Stress: -152447196.4238).
# Combination 24 (h=0.1500, bf=0.1500, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0223, Stress: -100485043.9907).
# Combination 25 (h=0.1500, bf=0.1500, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0218, Stress: -97062641.8472).
# Combination 26 (h=0.1500, bf=0.1500, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0214, Stress: -93729004.4323).
# Combination 27 (h=0.1500, bf=0.1500, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: -0.0150, Stress: -48144962.1426).
# Combination 28 (h=0.1500, bf=0.1500, tf=0.0120, tw=0.0060) FAILED constraints (Deflection: -0.0148, Stress: -46236730.7287).
# Combination 29 (h=0.1500, bf=0.1500, tf=0.0120, tw=0.0070) FAILED constraints (Deflection: -0.0145, Stress: -44363170.0292).
# Combination 30 (h=0.1500, bf=0.1500, tf=0.0120, tw=0.0090) FAILED constraints (Deflection: -0.0140, Stress: -40716348.6196).
# Combination 31 (h=0.2000, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0231, Stress: -195542576.9347).
# Combination 32 (h=0.2000, bf=0.1000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0192, Stress: -157984099.5231).
# Combination 33 (h=0.2000, bf=0.1000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0181, Stress: -147497502.5053).
# Combination 34 (h=0.2000, bf=0.1000, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0136, Stress: -103984536.8418).
# Combination 35 (h=0.2000, bf=0.1000, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0129, Stress: -97163494.8807).
# Combination 36 (h=0.2000, bf=0.1000, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0122, Stress: -90686069.2782).
# Combination 37 (h=0.2000, bf=0.1000, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: -0.0083, Stress: -52704650.2341).
# Combination 38 (h=0.2000, bf=0.1000, tf=0.0120, tw=0.0060) FAILED constraints (Deflection: -0.0078, Stress: -48671659.6508).
# Combination 39 (h=0.2000, bf=0.1000, tf=0.0120, tw=0.0070) FAILED constraints (Deflection: -0.0074, Stress: -44788758.4843).
# Combination 40 (h=0.2000, bf=0.1000, tf=0.0120, tw=0.0090) FAILED constraints (Deflection: -0.0067, Stress: -37440913.0426).
# Combination 41 (h=0.2000, bf=0.1500, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0125, Stress: -93675590.1847).
# Combination 42 (h=0.2000, bf=0.1500, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0095, Stress: -64764660.1626).
# Combination 43 (h=0.2000, bf=0.1500, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0090, Stress: -59474132.9543).
# Combination 44 (h=0.2000, bf=0.1500, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0053, Stress: -24129486.7292).
# Combination 45 (h=0.2000, bf=0.1500, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0049, Stress: -20784855.0308).
# Combination 46 (h=0.2000, bf=0.1500, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0046, Stress: -17559563.1249).
# Combination 47 (h=0.2000, bf=0.1500, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: -0.0014, Stress: 13477162.7552).
# Combination 48 (h=0.2000, bf=0.1500, tf=0.0120, tw=0.0060) FAILED constraints (Deflection: -0.0012, Stress: 15402263.9610).
# Combination 49 (h=0.2000, bf=0.1500, tf=0.0120, tw=0.0070) FAILED constraints (Deflection: -0.0010, Stress: 17277435.0068).
# Combination 50 (h=0.2000, bf=0.1500, tf=0.0120, tw=0.0090) FAILED constraints (Deflection: -0.0006, Stress: 20885560.2328).
# Combination 51 (h=0.2000, bf=0.2000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0067, Stress: -37180995.3276).
# Combination 52 (h=0.2000, bf=0.2000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0042, Stress: -13810731.9321).
# Combination 53 (h=0.2000, bf=0.2000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0039, Stress: -10630053.9769).
# Combination 54 (h=0.2000, bf=0.2000, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0008, Stress: 18633679.4326).
# Combination 55 (h=0.2000, bf=0.2000, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0006, Stress: 20613516.8537).
# Combination 56 (h=0.2000, bf=0.2000, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0004, Stress: 22538664.8952).
# Combination 61 (h=0.2500, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0083, Stress: -106165886.7888).
# Combination 62 (h=0.2500, bf=0.1000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0060, Stress: -79009026.5105).
# Combination 63 (h=0.2500, bf=0.1000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: -0.0052, Stress: -69399934.7941).
# Combination 64 (h=0.2500, bf=0.1000, tf=0.0090, tw=0.0050) FAILED constraints (Deflection: -0.0027, Stress: -39351951.9905).
# Combination 65 (h=0.2500, bf=0.1000, tf=0.0090, tw=0.0060) FAILED constraints (Deflection: -0.0022, Stress: -32947780.2423).
# Combination 66 (h=0.2500, bf=0.1000, tf=0.0090, tw=0.0070) FAILED constraints (Deflection: -0.0017, Stress: -26942268.9571).
# Combination 67 (h=0.2500, bf=0.1000, tf=0.0120, tw=0.0050) FAILED constraints (Deflection: 0.0005, Stress: -979345.1051).
# Combination 71 (h=0.2500, bf=0.1500, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0022, Stress: -32819127.7397).
# Combination 72 (h=0.2500, bf=0.1500, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: -0.0004, Stress: -11298235.9845).
# Combination 73 (h=0.2500, bf=0.1500, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: 0.0000, Stress: -6305548.5811).
# Combination 101 (h=0.3000, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: -0.0006, Stress: -48985367.6805).
# Combination 102 (h=0.3000, bf=0.1000, tf=0.0070, tw=0.0050) FAILED constraints (Deflection: 0.0008, Stress: -28441153.6384).
# Combination 103 (h=0.3000, bf=0.1000, tf=0.0070, tw=0.0060) FAILED constraints (Deflection: 0.0014, Stress: -19642032.3521).
# Combination 151 (h=0.3500, bf=0.1000, tf=0.0060, tw=0.0050) FAILED constraints (Deflection: 0.0038, Stress: -9594141.5141).
#
# Found 70 combinations that failed one or more constraints within the first 450 generated.

# %%
# prompt: Visualisasi Volume Baja Profil dan Titik Optimum

import matplotlib.pyplot as plt
import numpy as np
# Find the optimum combination and its volume
if passing_combinations:
    best_volume = float('inf')
    best_combo = None

    for combo in passing_combinations:
        current_volume = objective_function(combo)
        if current_volume < best_volume:
            best_volume = current_volume
            best_combo = combo

    print(f"\nCombination with minimum volume among passing combinations:")
    print(f"h={best_combo[0]:.4f} m, bf={best_combo[1]:.4f} m, tf={best_combo[2]:.4f} m, tw={best_combo[3]:.4f} m")
    print(f"Minimum Volume: {best_volume:.6f} m^3")
else:
    print("\nNo combinations found that satisfy all constraints within the first 450 generated.")
    best_combo = None # Set to None if no optimum found

# --- 5. Visualisasi Volume (Updated) ---

# Buat rentang nilai untuk bf dan h
bf_range = np.linspace(0.0, 0.5, 50)  # Rentang lebar flange (m)
h_range = np.linspace(0.1, 1.0, 50)  # Rentang tinggi profil (m)

# Asumsi nilai tf dan tw yang tetap untuk simplifikasi visualisasi permukaan
tf_fixed = 0.01  # Tebal flange (m) - contoh
tw_fixed = 0.006  # Tebal web (m) - contoh

# Buat grid untuk bf dan h
BF, H = np.meshgrid(bf_range, h_range)

# Hitung volume untuk setiap kombinasi bf dan h (menggunakan tf_fixed, tw_fixed)
VOLUME = objective_function([H, BF, np.full_like(BF, tf_fixed), np.full_like(BF, tw_fixed)])

# Buat plot 3D
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot permukaan volume
surf = ax.plot_surface(BF, H, VOLUME, cmap='viridis', edgecolor='none', alpha=0.8) # Use alpha for transparency

# Filter the passing combinations for plotting
passing_h = [combo[0] for combo in passing_combinations]
passing_bf = [combo[1] for combo in passing_combinations]
passing_volumes = [objective_function(combo) for combo in passing_combinations]

# Plot the passing combinations as points
if passing_combinations:
    ax.scatter(passing_bf, passing_h, passing_volumes, c='red', marker='o', s=50, label='Kombinasi Lulus Kendala')

# Plot the optimum point if found
if best_combo:
    optimum_h, optimum_bf, optimum_tf, optimum_tw = best_combo
    optimum_volume = objective_function(best_combo)
    ax.scatter(optimum_bf, optimum_h, optimum_volume, c='cyan', marker='*', s=200, label='Titik Optimum (Min Volume)')

# Atur label sumbu
ax.set_xlabel('Lebar Flange, bf (m)')
ax.set_ylabel('Tinggi Profil, h (m)')
ax.set_zlabel('Volume Baja Profil (m^3)')
ax.set_title('Visualisasi Volume Baja Profil dan Titik Optimum\n(Permukaan diasumsikan tf dan tw tetap)')

# Tambahkan color bar
fig.colorbar(surf, label='Volume (m^3)')

# Add a legend to the plot
ax.legend()

# Adjust viewpoint for better visualization (optional)
ax.view_init(60, 40)

# Show the plot
plt.show()
# Out:
# Combination with minimum volume among passing combinations:
# h=0.3500 m, bf=0.1000 m, tf=0.0070 m, tw=0.0050 m
# Minimum Volume: 0.015750 m^3

# %%
# prompt: code untuk menampilkan area lulus tegangan dan lendutan

import matplotlib.pyplot as plt
import numpy as np
deflection_limit_surface = np.full_like(BF, np.nan) # Use NaN for regions where constraint is not met
stress_limit_surface = np.full_like(BF, np.nan) # Use NaN for regions where constraint is not met

# Calculate constraint values for the meshgrid (using fixed tf and tw)
for i in range(BF.shape[0]):
    for j in range(BF.shape[1]):
        h_val = H[i, j]
        bf_val = BF[i, j]
        # Check basic geometry constraints (bf <= h, tf > tw) - simplified for visualization
        if bf_val <= h_val and tf_fixed > tw_fixed:
            params = [h_val, bf_val, tf_fixed, tw_fixed]
            # Evaluate deflection constraint
            deflection_const_val = deflection_constraint(params)
            if deflection_const_val >= 0:
                deflection_limit_surface[i, j] = VOLUME[i, j] # Show volume if deflection constraint is met

            # Evaluate stress constraint
            stress_const_val = stress_constraint(params)
            if stress_const_val >= 0:
                stress_limit_surface[i, j] = VOLUME[i, j] # Show volume if stress constraint is met

# Create a combined surface for the feasible region (where both constraints are met)
feasible_surface = np.full_like(BF, np.nan)
for i in range(BF.shape[0]):
    for j in range(BF.shape[1]):
         h_val = H[i, j]
         bf_val = BF[i, j]
         # Check basic geometry constraints (bf <= h, tf > tw) - simplified for visualization
         if bf_val <= h_val and tf_fixed > tw_fixed:
            params = [h_val, bf_val, tf_fixed, tw_fixed]
            deflection_ok = deflection_constraint(params) >= 0
            stress_ok = stress_constraint(params) >= 0
            if deflection_ok and stress_ok:
                 feasible_surface[i, j] = VOLUME[i, j] # Show volume if both constraints are met


# Buat plot 3D baru untuk area lulus kendala
fig_constraints = plt.figure(figsize=(12, 10))
ax_constraints = fig_constraints.add_subplot(111, projection='3d')

# Plot permukaan volume transparan
surf_volume = ax_constraints.plot_surface(BF, H, VOLUME, cmap='viridis', edgecolor='none', alpha=0.3, label='Volume (Diasumsikan tf, tw Tetap)')

# Plot permukaan area lulus lendutan (berwarna biru)
surf_deflection_pass = ax_constraints.plot_surface(BF, H, deflection_limit_surface, color='blue', alpha=0.6, label='Area Lulus Kendala Lendutan')

# Plot permukaan area lulus tegangan (berwarna hijau)
surf_stress_pass = ax_constraints.plot_surface(BF, H, stress_limit_surface, color='green', alpha=0.6, label='Area Lulus Kendala Tegangan')

# Plot permukaan area lulus kedua kendala (feasible region) (berwarna merah)
surf_feasible = ax_constraints.plot_surface(BF, H, feasible_surface, color='red', alpha=0.8, label='Area Lulus Kedua Kendala (Feasible Region)')

# Plot the passing combinations as points (if any)
if passing_combinations:
    ax_constraints.scatter(passing_bf, passing_h, passing_volumes, c='black', marker='o', s=50, label='Kombinasi dalam Daftar Lulus')

# Plot the optimum point if found
if best_combo:
    optimum_h, optimum_bf, optimum_tf, optimum_tw = best_combo
    optimum_volume = objective_function(best_combo)
    ax_constraints.scatter(optimum_bf, optimum_h, optimum_volume, c='cyan', marker='*', s=200, label='Titik Optimum (Min Volume di Feasible Region)')


# Atur label sumbu
ax_constraints.set_xlabel('Lebar Flange, bf (m)')
ax_constraints.set_ylabel('Tinggi Profil, h (m)')
ax_constraints.set_zlabel('Volume Baja Profil (m^3)')
ax_constraints.set_title('Visualisasi Area Lulus Kendala Tegangan dan Lendutan')

# Buat proxy seniman untuk legenda permukaan
# Ini diperlukan karena plot_surface tidak secara otomatis membuat handle legenda
surf_volume._facecolors2d=surf_volume._facecolor3d
surf_volume._edgecolors2d=surf_volume._edgecolor3d

surf_deflection_pass._facecolors2d=surf_deflection_pass._facecolor3d
surf_deflection_pass._edgecolors2d=surf_deflection_pass._edgecolor3d

surf_stress_pass._facecolors2d=surf_stress_pass._facecolor3d
surf_stress_pass._edgecolors2d=surf_stress_pass._edgecolor3d

surf_feasible._facecolors2d=surf_feasible._facecolor3d
surf_feasible._edgecolors2d=surf_feasible._edgecolor3d


# Add a legend to the plot
ax_constraints.legend()

# Adjust viewpoint for better visualization (optional)
ax_constraints.view_init(60, 40)

# Show the plot
plt.show()
